# %% [markdown]
# **1. Scraping Data Review From Google Play**

# %%
# Mengimpor pustaka yang dibutuhkan
# !pip install google-play-scraper
import pandas as pd
import csv # Menyimpan ulasan dalam file CSV
from google_play_scraper import app, reviews, Sort, reviews_all # Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
# ...

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all

scrapreview = reviews_all(
    'com.grabtaxi.passenger', # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=30000             # Jumlah maksimum ulasan yang ingin diambil
)

import pandas as pd

app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()

app_reviews_df = app_reviews_df[['content']]

app_reviews_df.to_csv('ulasan_aplikasi_grab.csv', index=False)

app_reviews_df.head()
# Out:
#                                              content
# 0  apk nya bagus si banyak promo nya harga go rid...
# 1  Halo grab, hari ini saya mau buka aplikasi, ke...
# 2  sbg pengguna grab dari lama,khusus nya grabfoo...
# 3  Aplikasinya jd lambat. Entah iklan videonya yg...
# 4  Saya driver dan pengguna, dan saya mengedukasi...

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108000 entries, 0 to 107999
# Data columns (total 1 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   content  108000 non-null  object
# dtypes: object(1)
# memory usage: 843.9+ KB

# %%
# generate requirement.txt

# !pip freeze > requirements.txt
